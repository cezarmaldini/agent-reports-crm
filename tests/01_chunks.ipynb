# %%
import os
import uuid
import json
import logging
from typing import List, Dict, Any, Iterable

from docling.document_converter import DocumentConverter
from docling.chunking import HybridChunker
from fastembed import TextEmbedding

import clients

# %%
def list_files(folder: str) -> List[str]:
    files = [
        os.path.join(folder, f)
        for f in os.listdir(folder)
        if f.lower().endswith('.md')
    ]
    files.sort()
    return files

# %%
def convert_doc(converter: DocumentConverter, file_path: str):

    return converter.convert(file_path)

# %%
def chunk_document(chunker: HybridChunker, doc):
    
    return chunker.chunk(dl_doc=doc)

# %%
def chunks(file_path: str, converter: DocumentConverter, chunker: HybridChunker):
    doc = convert_doc(converter, file_path)

    # corrige ordem dos argumentos
    chunk_iter = chunk_document(chunker, doc.document)

    chunks = list(chunk_iter)

    for i, chunk in enumerate(chunks):
        print(f"=== {i} ===")
        print(f"chunk.text:\n{f'{chunk.text[:300]}…'!r}")

        enriched_text = chunker.contextualize(chunk=chunk)
        print(f"chunker.contextualize(chunk):\n{f'{enriched_text[:300]}…'!r}")
        print()

    return chunks

# %%
files = list_files(folder='markdown')

converter = DocumentConverter()

chunker_tokenizer = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"

chunker = HybridChunker(tokenizer=chunker_tokenizer, max_tokens=768,merge_peers=True)

for file in files:
    print(f'✅ Arquivo: {file}')
    chunks(file_path=file, converter=converter, chunker=chunker)
# Out:
# INFO:docling.datamodel.document:detected formats: [<InputFormat.MD: 'md'>]
# INFO:docling.document_converter:Going to convert document batch...
# INFO:docling.document_converter:Initializing pipeline for SimplePipeline with options hash 4cc01982ae99b46a2a63fcda46c47c35
# INFO:docling.pipeline.base_pipeline:Processing document arquivo_01.md
# ✅ Arquivo: markdown\arquivo_01.md
# INFO:docling.document_converter:Finished converting document arquivo_01.md in 0.44 sec.
# INFO:docling.datamodel.document:detected formats: [<InputFormat.MD: 'md'>]
# INFO:docling.document_converter:Going to convert document batch...
# INFO:docling.pipeline.base_pipeline:Processing document arquivo_02.md
# === 0 ===
# chunk.text:
# 'O desafio proposto consiste em atuar como cientista de dados de um hospital para desenvolver um sistema preditivo capaz de estimar o\n**nível de obesidade**\nde um paciente com base em características pessoais, hábitos alimentares e estilo de vida.…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n📌 Contextualização do Problema\nO desafio proposto consiste em atua…'
#
# === 1 ===
# chunk.text:
# 'A análise exploratória foi conduzida no\n**Microsoft Fabric**\natravés do notebook\n[```\nnb_analise_exploratoria.ipynb\n```](nb_analise_exploratoria.ipynb)\n.\nPrincipais pontos abordados:\n- Distribuição das variáveis categóricas e numéricas\n- Correlações entre variáveis\n- Transformações aplicadas para no…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🔎 Análise Exploratória\nA análise exploratória foi conduzida no\n**M…'
#
# === 2 ===
# chunk.text:
# 'O treinamento do modelo foi feito também no\n**Microsoft Fabric**\n, utilizando o notebook\n[```\nnb_modelo_preditivo.ipynb\n```](nb_modelo_preditivo.ipynb)\n.…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🤖 Treinamento do Modelo Preditivo\nO treinamento do modelo foi feit…'
#
# === 3 ===
# chunk.text:
# '- **RandomForestClassifier**…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🤖 Treinamento do Modelo Preditivo\nAlgoritmo Utilizado:\n- **RandomF…'
#
# === 4 ===
# chunk.text:
# '```\nAcurácia: 0.9196\n\n              precision    recall  f1-score   support\n\n  Obesidade Grau I       0.96      0.96      0.96        70\n Obesidade Grau II       0.98      1.00      0.99        60\nObesidade Grau III       1.00      1.00      1.00        65\n Peso Insuficiente       0.88      0.93    …'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🤖 Treinamento do Modelo Preditivo\nMétricas de Desempenho:\n```\nAcur…'
#
# === 5 ===
# chunk.text:
# 'A aplicação foi desenvolvida com\n**Streamlit**\n, e o código principal encontra-se em\n[```\napp.py\n```](app.py)\n.…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🌐 Aplicação com Streamlit\nA aplicação foi desenvolvida com\n**Strea…'
#
# === 6 ===
# chunk.text:
# '- Métricas gerais e distribuição dos níveis de obesidade\n- Análises interativas de:\n- Gênero\n- Histórico familiar de obesidade\n- Hábito de fumar\n- Consumo de alimentos calóricos\n- Comportamentos:\n- Comer entre refeições\n- Consumo de álcool\n- Meio de transporte utilizado\n- Correlações:\n- Nível de obe…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🌐 Aplicação com Streamlit\nFuncionalidades\n📊 Dashboard Analítico\n- …'
#
# === 7 ===
# chunk.text:
# '- Formulário para entrada de dados de pacientes\n- Gênero, idade, peso\n- Hábitos alimentares e estilo de vida\n- Resultado previsto:\n- Nível de obesidade (7 possíveis categorias)\n- Mensagem orientativa com base no resultado\n- Modelo treinado previamente e carregado no início da aplicação\nO objetivo da…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🌐 Aplicação com Streamlit\nFuncionalidades\n🧪 Previsão com Modelo Pr…'
#
# === 8 ===
# chunk.text:
# '🔗\n[tech-challenge-fase3.onrender.com](https://tech-challenge-fase04.onrender.com/)…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🌐 Aplicação com Streamlit\nAcesse a Solução:\n🔗\n[tech-challenge-fase…'
#
# === 9 ===
# chunk.text:
# '- \nOs dados utilizados na aplicação foram\n**persistidos em um banco de dados PostgreSQL**\n, permitindo:\n- Armazenamento estruturado e seguro\n- Integração direta com o modelo preditivo para previsões em tempo real\n- Possibilidade de expansão futura da base com novos dados clínicos…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🛢 Banco de Dados\n- \nOs dados utilizados na aplicação foram\n**persi…'
#
# === 10 ===
# chunk.text:
# 'A aplicação foi\n**containerizada com Docker**\ne publicada na nuvem utilizando a plataforma\n**Render Cloud**\n, garantindo:\n- Deploy automatizado e escalável\n- Ambiente isolado e replicável para produção\n- Facilidade de atualização contínua…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🚀 Deploy\nA aplicação foi\n**containerizada com Docker**\ne publicada…'
#
# === 11 ===
# chunk.text:
# 'Linguagem, Ferramenta/Ferramentas = Python 3.11. Ambiente Notebook, Ferramenta/Ferramentas = Microsoft Fabric. Machine Learning, Ferramenta/Ferramentas = scikit-learn, pandas, numpy. Visualização, Ferramenta/Ferramentas = Plotly, Streamlit. Dashboard Interativo, Ferramenta/Ferramentas = Streamlit + …'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🧰 Tecnologias Utilizadas\nLinguagem, Ferramenta/Ferramentas = Pytho…'
#
# === 12 ===
# chunk.text:
# '📦 Arquivo\n```\nrequirements.txt\n```\nAbaixo estão listadas todas as dependências utilizadas no projeto, e que devem ser instaladas para o correto funcionamento da aplicação:\n```\nstreamlit\nstreamlit-option-menu\npandas\nplotly\npython-dotenv\nsqlalchemy\npsycopg2-binary\nscikit-learn\n```\nVocê pode instalar t…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n\n📦 Arquivo\n```\nrequirements.txt\n```\nAbaixo estão listadas todas as…'
#
# === 13 ===
# chunk.text:
# 'O projeto está preparado para ser executado em um container Docker. O arquivo Dockerfile contém a seguinte configuração:\n```\n# Imagem base oficial do Python\nFROM python:3.11\n\n# Define o diretório de trabalho no container\nWORKDIR /app\n\n# Copia os arquivos da aplicação para o container\nCOPY . /app\n\n# …'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n🐳 Dockerfile\nO projeto está preparado para ser executado em um con…'
#
# === 14 ===
# chunk.text:
# 'Se você gostou deste projeto e ele foi útil de alguma forma, considere deixar uma estrela ⭐ no repositório para apoiar o trabalho!\nDesenvolvido por:\n👨\u200d💻 Cézar Maldini Rocha Almeida…'
# chunker.contextualize(chunk):
# 'Projeto desenvolvido como parte da Fase 4 da PÓS TECH em Data Analytics, com o objetivo de aplicar técnicas de ciência de dados e machine learning para prever níveis de obesidade, apoiando equipes médicas em diagnósticos preventivos.\n⭐ Contribua com o Projeto\nSe você gostou deste projeto e ele foi ú…'
#
# ✅ Arquivo: markdown\arquivo_02.md
# INFO:docling.document_converter:Finished converting document arquivo_02.md in 0.47 sec.
# === 0 ===
# chunk.text:
# '# Este projeto foi desenvolvido como parte do\n**Tech Challenge - Fase 3**\nda Pós-Tech em Engenharia de Dados, com o objetivo de transformar os dados da\n**PNAD COVID-19**\n, disponibilizados pelo IBGE, em informações acessíveis e relevantes para a tomada de decisão em saúde pública.…'
# chunker.contextualize(chunk):
# '# Este projeto foi desenvolvido como parte do\n**Tech Challenge - Fase 3**\nda Pós-Tech em Engenharia de Dados, com o objetivo de transformar os dados da\n**PNAD COVID-19**\n, disponibilizados pelo IBGE, em informações acessíveis e relevantes para a tomada de decisão em saúde pública.…'
#
# === 1 ===
# chunk.text:
# 'Durante a pandemia de COVID-19, compreender o comportamento da população, os sintomas clínicos mais comuns e os impactos sociais e econômicos tornou-se uma prioridade para instituições de saúde.\nO IBGE disponibilizou a pesquisa\n**PNAD COVID-19**\n, com dados valiosos, porém brutos e descentralizados.…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🔍 1. Contextualização do Problema\nDurante a pandemia de COVID-19, compreender o comportamento da população, os sintomas clínicos mais comuns e os impactos sociais e econômicos tornou-se uma prioridade para instituições de saúde.\nO IBGE disponibilizou a pes…'
#
# === 2 ===
# chunk.text:
# 'Foi desenvolvida uma\n**arquitetura moderna de dados e analytics**\n, capaz de:\n- Organizar e transformar dados brutos em camadas (Bronze, Silver, Gold) no **Microsoft Fabric** .\n- Oferecer uma **interface interativa** via **Streamlit** .\n- Fornecer insights sobre sintomas, renda, escolaridade, raça/c…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🧩 2. Solução\nFoi desenvolvida uma\n**arquitetura moderna de dados e analytics**\n, capaz de:\n- Organizar e transformar dados brutos em camadas (Bronze, Silver, Gold) no **Microsoft Fabric** .\n- Oferecer uma **interface interativa** via **Streamlit** .\n- Forn…'
#
# === 3 ===
# chunk.text:
# 'Arquitetura da Solução…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🧩 2. Solução\nArquitetura da Solução\nArquitetura da Solução…'
#
# === 4 ===
# chunk.text:
# '- `A002` – Idade do morador\n- `A003` – Sexo\n- `A004` – Cor ou raça\n- `B009B/D/F` – Resultados de exames (SWAB, sangue dedo, sangue veia)\n- `C007C` , `C01011` – Trabalho e faixa de rendimento\n- `D0031` , `D0051` – Programas sociais\n- `F001` , `F0022` – Dados de moradia…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🧩 2. Solução\nQuestionamentos Utilizados (Exemplos)\n- `A002` – Idade do morador\n- `A003` – Sexo\n- `A004` – Cor ou raça\n- `B009B/D/F` – Resultados de exames (SWAB, sangue dedo, sangue veia)\n- `C007C` , `C01011` – Trabalho e faixa de rendimento\n- `D0031` , `D…'
#
# === 5 ===
# chunk.text:
# 'Setembro, Outubro e Novembro de 2020…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🧩 2. Solução\nMeses Analisados\nSetembro, Outubro e Novembro de 2020…'
#
# === 6 ===
# chunk.text:
# '🔗\n[tech-challenge-fase3.onrender.com](https://tech-challenge-fase3.onrender.com/)…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🧩 2. Solução\nAcesse a Solução:\n🔗\n[tech-challenge-fase3.onrender.com](https://tech-challenge-fase3.onrender.com/)…'
#
# === 7 ===
# chunk.text:
# 'O pipeline segue a arquitetura\n**medalhão**\ne foi implementado no\n**Microsoft Fabric**\n:\n```\nnb_dados_silver.ipynb\n```\n,\n```\nnb_dicionarios_silver.ipynb\n```\n```\nnb_dados_gold.ipynb\n```\n🥉 Bronze, Descrição = Dados brutos (CSV) carregados no Lakehouse.. 🥉 Bronze, Notebook = –. 🥈 Silver, Descrição = Li…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🔄 3. Pipeline de Dados\nO pipeline segue a arquitetura\n**medalhão**\ne foi implementado no\n**Microsoft Fabric**\n:\n```\nnb_dados_silver.ipynb\n```\n,\n```\nnb_dicionarios_silver.ipynb\n```\n```\nnb_dados_gold.ipynb\n```\n🥉 Bronze, Descrição = Dados brutos (CSV) carrega…'
#
# === 8 ===
# chunk.text:
# 'Dicionários\nDados…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🔄 3. Pipeline de Dados\nVisualizações das Camadas\nBronze\nDicionários\nDados…'
#
# === 9 ===
# chunk.text:
# '```\nnb_dicionarios_silver.ipynb\n```\n```\nnb_dados_silver.ipynb\n```\nSilver 1\nSilver 2…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🔄 3. Pipeline de Dados\nVisualizações das Camadas\nSilver\n```\nnb_dicionarios_silver.ipynb\n```\n```\nnb_dados_silver.ipynb\n```\nSilver 1\nSilver 2…'
#
# === 10 ===
# chunk.text:
# '```\nnb_dados_gold.ipynb\n```\nGold…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🔄 3. Pipeline de Dados\nVisualizações das Camadas\nGold\n```\nnb_dados_gold.ipynb\n```\nGold…'
#
# === 11 ===
# chunk.text:
# 'Interface desenvolvida com\n**Streamlit**\n:\n- Dashboards por **estado e período**\n- Filtros por **mês, estado e tipo de exame**\n- Análises por **sexo, faixa etária, cor/raça, escolaridade e renda**\n- Visualizações: **gráficos de barras, roscas e mapas interativos**…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n📈 4. Analytics\nInterface desenvolvida com\n**Streamlit**\n:\n- Dashboards por **estado e período**\n- Filtros por **mês, estado e tipo de exame**\n- Análises por **sexo, faixa etária, cor/raça, escolaridade e renda**\n- Visualizações: **gráficos de barras, rosca…'
#
# === 12 ===
# chunk.text:
# 'Microsoft Fabric, Uso = Lakehouse, Notebooks, Delta/Parquet. PySpark, Uso = Processamento de dados. SQL, Uso = Consultas de análise. Streamlit, Uso = Interface Web. Plotly, Uso = Visualizações interativas. GitHub, Uso = Versionamento e CI/CD. Render, Uso = Hospedagem da aplicação…'
# chunker.contextualize(chunk):
# 'Este projeto foi desenvolvido como parte do\n🛠️ 5. Tecnologias Utilizadas\nMicrosoft Fabric, Uso = Lakehouse, Notebooks, Delta/Parquet. PySpark, Uso = Processamento de dados. SQL, Uso = Consultas de análise. Streamlit, Uso = Interface Web. Plotly, Uso = Visualizações interativas. GitHub, Uso = Version…'
